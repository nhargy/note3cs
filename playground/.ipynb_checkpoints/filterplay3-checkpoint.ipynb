# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
from scipy.stats import chisquare

plt.rcParams['figure.figsize'] = 20, 10
plt.style.use('dark_background')

# %%
# FUNCTIONS

def line(x, b):
    return b

def gauss(x, A, s, m):
    return A * (np.exp(-(x-m)**2/(2*(s**2))))

def double_gauss(x,A1, A2, s1, s2, m1, m2):
    return gauss(x, A1, s1, m1) + gauss(x, A2, s2, m2)

def gen_noise(s, size=800):
    return s * np.random.randn(size)

def gen_gauss_signal(ns, A, s, m, size=800):
    noise = gen_noise(ns, size=size)
    sig      =  [gauss(x, A, s, m) for x in range(size)]
    return sig+noise, noise

def gen_double_gauss_signal(ns, A1, A2, s1, s2, m1, m2, size = 800):
    noise = gen_noise(ns, size=size)
    sig      =  [double_gauss(x, A1, A2, s1, s2, m1, m2) for x in range(size)]
    return sig+noise, noise

def grid_it():
    plt.grid(True, which='both', linestyle='-', linewidth=0.75, color='gray')
    plt.minorticks_on()
    plt.grid(b=True, which='minor', color='lightgray', linestyle='--', linewidth=0.25) 
    plt.legend()

def moving_average(x_array, y_array, window):

    new_x      = []
    avr_array = []
    for i in range(window, len(y_array) - window):

        new_x.append(x_array[i])
        
        val = 0
        for j in range(1, window):
            val+= y_array[i+j]
            val+=y_array[i-j]
        val+= y_array[i]
        avr_array.append(val/(window*2 +1))
    
    return new_x, avr_array

def chi_squared(obs, exp):

    chi_arr = np.divide(( ( np.subtract(obs, exp) ) ** 2 ), exp )
    chi         = np.sum(chi_arr)
    
    return chi

def chi_sq(obs, exp):
    size = len(obs)
    chi = 0
    for i in range(size):

        val = ( (obs[i] - exp[i])**2 )
        chi+=val
        
    return chi / size

# %%
# GAUSSIAN PARAMETERS
A1 = 10; s1 = 30; m1 = 200
A2 = 3; s2 = 80; m2 = 400

noise_std = 1.5

window = 10

# -- SIG SIM -- #

# data
y_arr, noise = gen_double_gauss_signal(noise_std, A1,A2, s1,s2, m1,m2)
x_arr = np.arange(0, len(y_arr))
plt.scatter(x_arr, y_arr, color='yellow', s = 2, marker = 'X', label = 'data')

# moving average
x_avr, y_avr = moving_average(x_arr, y_arr, window)
plt.scatter(x_avr, y_avr, color='cyan', s = 2, marker = 'X', label = 'moving average')

# signal
y_sig     =  [double_gauss(x, A1, A2, s1, s2, m1, m2) for x in range(800)]
plt.scatter(x_arr, y_sig, color='red', s = 2, marker = 'X', label = 'signal')


# ---------
# best fit
popt, pcov = curve_fit(double_gauss, x_arr, y_arr , p0 = [1, 1, 10,10, 400,400])
fit_arr     = np.array([double_gauss(x, *popt) for x in range(800)])
plt.scatter(x_arr, fit_arr, s = 2, color = 'fuchsia', marker = 'X', label = 'best fit')

chi_sig      = chi_sq(y_arr, fit_arr)

# ----------

grid_it()
plt.title('Signal Simulation', fontsize = 40)

# Get the y-limits
y_limits = plt.gca().get_ylim()

# Extract the minimum and maximum y-values
y_min, y_max = y_limits

plt.show();

# --- NOISE --- #

# data
plt.scatter(x_arr, noise, color='yellow', s = 2, marker = 'X', label = 'noise')

# moving average
x_avr, y_avr = moving_average(x_arr, noise, window)
plt.scatter(x_avr, y_avr, color='cyan', s = 2, marker = 'X', label = 'moving average')

# best fit
popt, pcov = curve_fit(double_gauss, x_arr, noise , p0 = [5, 5, 50,50, 200,400])
fit_arr_noise     = np.array([double_gauss(x, *popt) for x in range(800)])
plt.scatter(x_arr, fit_arr_noise, s = 2, color = 'greenyellow', marker = 'X', label = 'best fit')

chisq_nosig = chi_squared(noise, fit_arr_noise)
chi_nosig     = chi_sq(noise, fit_arr_noise)

grid_it()
plt.title('Noise Only Simulation', fontsize = 40)
plt.ylim(y_min, y_max)
plt.show();
# Out:
# /tmp/ipykernel_95968/139122419.py:25: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='minor', color='lightgray', linestyle='--', linewidth=0.25)

# %%
# GAUSSIAN PARAMETERS
A = 5; s = 50; m = 500

noise_std = 1

window = 10

# -- SIG SIM -- #

# data
y_arr, noise = gen_gauss_signal(noise_std, A,s,m)
x_arr = np.arange(0, len(y_arr))
plt.scatter(x_arr, y_arr, color='yellow', s = 2, marker = 'X', label = 'data')

# moving average
x_avr, y_avr = moving_average(x_arr, y_arr, window)
plt.scatter(x_avr, y_avr, color='cyan', s = 2, marker = 'X', label = 'moving average')

# signal
y_sig     =  [gauss(x, A,s,m) for x in range(800)]
plt.scatter(x_arr, y_sig, color='red', s = 2, marker = 'X', label = 'signal')


# ---------
# best fit
popt, pcov = curve_fit(gauss, x_arr, y_arr , p0 = [1, 50, 400])
fit_arr     = np.array([gauss(x, *popt) for x in range(800)])
plt.scatter(x_arr, fit_arr, s = 2, color = 'fuchsia', marker = 'X', label = 'best fit')

chi_sig      = chi_sq(y_arr, fit_arr)

# ----------

grid_it()
plt.title('Signal Simulation', fontsize = 40)

# Get the y-limits
y_limits = plt.gca().get_ylim()

# Extract the minimum and maximum y-values
y_min, y_max = y_limits

plt.show();

# --- NOISE --- #

# data
plt.scatter(x_arr, noise, color='yellow', s = 2, marker = 'X', label = 'noise')

# moving average
x_avr, y_avr = moving_average(x_arr, noise, window)
plt.scatter(x_avr, y_avr, color='cyan', s = 2, marker = 'X', label = 'moving average')

# best fit
popt, pcov = curve_fit(gauss, x_arr, noise , p0 = [5,50,400])
fit_arr_noise     = np.array([gauss(x, *popt) for x in range(800)])
plt.scatter(x_arr, fit_arr_noise, s = 2, color = 'greenyellow', marker = 'X', label = 'best fit')

chi_nosig     = chi_sq(noise, fit_arr_noise)

grid_it()
plt.title('Noise Only Simulation', fontsize = 40)
plt.ylim(y_min, y_max)
plt.show();

print(chi_sig, chi_nosig)
# Out:
# /tmp/ipykernel_95968/139122419.py:25: MatplotlibDeprecationWarning: The 'b' parameter of grid() has been renamed 'visible' since Matplotlib 3.5; support for the old name will be dropped two minor releases later.
#   plt.grid(b=True, which='minor', color='lightgray', linestyle='--', linewidth=0.25)
# 0.99150863408422 0.9868040531103854

# %%
( ( y_arr[1] -  fit_arr[1] ) ** 2 ) / fit_arr[1]
# Out:
# 6.329838841385071e+20

# %%
offs = 100
y_arr_offs = y_arr + offs
fit_arr_offs = fit_arr + offs

plt.plot(y_arr_offs)
plt.plot(fit_arr_offs)

chi = chi_sq(y_arr_offs, fit_arr_offs)
#chi2, p_value = chisquare(f_obs=y_arr_offs, f_exp=fit_arr_offs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_95968/131265875.py in <module>
#       7
#       8 chi = chi_sq(y_arr_offs, fit_arr_offs)
# ----> 9 chi2, p_value = chisquare(f_obs=y_arr_offs, f_exp=fit_arr_offs)
#
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py in chisquare(f_obs, f_exp, ddof, axis)
#    6909
#    6910     """
# -> 6911     return power_divergence(f_obs, f_exp=f_exp, ddof=ddof, axis=axis,
#    6912                             lambda_="pearson")
#    6913
#
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py in power_divergence(f_obs, f_exp, ddof, axis, lambda_)
#    6751                    f"of {rtol}, but the percent differences are:\n"
#    6752                    f"{relative_diff}")
# -> 6753             raise ValueError(msg)
#    6754
#    6755     else:
#
# ValueError: For each axis slice, the sum of the observed frequencies must agree with the sum of the expected frequencies to a relative tolerance of 1e-08, but the percent differences are:
# 0.000524069503142198

# %%
chi
# Out:
# 159.43048196549665

# %%
arr1 = [4,2,3,4,5,6,7,8,9,10]
arr2 = [4.75, 1.2, 3.1,3.9,5.5,5.9,7.8,8.9, 11.1, 13.2]

# %%
plt.plot(arr2); plt.plot(arr1)

# %%
c =  chi_sq(arr2, arr1)

# %%
c
# Out:
# 2.2248035714285708

# %%
def chi_squared_test(observed, expected):
    """
    Perform a chi-squared test for two arrays of observed and expected frequencies.

    Parameters:
    observed (array-like): An array of observed frequencies.
    expected (array-like): An array of expected frequencies.

    Returns:
    chi2 (float): The chi-squared test statistic.
    p_value (float): The p-value associated with the test.
    """
    observed = np.asarray(observed)
    expected = np.asarray(expected)

    # Check that observed and expected arrays have the same shape
    if observed.shape != expected.shape:
        raise ValueError("Observed and expected arrays must have the same shape.")

    # Perform the chi-squared test
    chi2, p_value = chisquare(f_obs=observed, f_exp=expected)

    return chi2, p_value

# %%
expected = [4, 2, 3, 4, 5, 6, 7, 8, 9, 10]
observed = [4.75, 1.2, 3.1, 3.9, 5.5, 5.9, 7.8, 8.9, 11.1, 13.2]
chi, p = chi_squared_test(observed,expected)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_95968/4059265655.py in <module>
#       1 expected = [4, 2, 3, 4, 5, 6, 7, 8, 9, 10]
#       2 observed = [4.75, 1.2, 3.1, 3.9, 5.5, 5.9, 7.8, 8.9, 11.1, 13.2]
# ----> 3 chi, p = chi_squared_test(observed,expected)
#
# /tmp/ipykernel_95968/1030230379.py in chi_squared_test(observed, expected)
#      19
#      20     # Perform the chi-squared test
# ---> 21     chi2, p_value = chisquare(f_obs=observed, f_exp=expected)
#      22
#      23     return chi2, p_value
#
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py in chisquare(f_obs, f_exp, ddof, axis)
#    6909
#    6910     """
# -> 6911     return power_divergence(f_obs, f_exp=f_exp, ddof=ddof, axis=axis,
#    6912                             lambda_="pearson")
#    6913
#
# /usr/lib/python3/dist-packages/scipy/stats/_stats_py.py in power_divergence(f_obs, f_exp, ddof, axis, lambda_)
#    6751                    f"of {rtol}, but the percent differences are:\n"
#    6752                    f"{relative_diff}")
# -> 6753             raise ValueError(msg)
#    6754
#    6755     else:
#
# ValueError: For each axis slice, the sum of the observed frequencies must agree with the sum of the expected frequencies to a relative tolerance of 1e-08, but the percent differences are:
# 0.12672413793103438

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Example data
observed = np.array([[10, 20, 30, 40, 50]])
expected = np.array([[12, 18, 28, 45, 55]])

# Perform the chi-squared test using chi2_contingency
chi2, p, _, _ = chi2_contingency(observed)

print("Observed counts:")
print(observed)
print("Expected counts:")
print(expected)
print(f"Chi-squared statistic: {chi2}")
print(f"P-value: {p}")
# Out:
# Observed counts:
# [[10 20 30 40 50]]
# Expected counts:
# [[12 18 28 45 55]]
# Chi-squared statistic: 0.0
# P-value: 1.0

# %%
#observed = np.array([20., 20., 0., 0.])
#expected = np.array([.25, .25, .25, .25]) * np.sum(observed)

observed = [20, 20, 0, 0]
expected = [10,10,10,10]

chisquare(observed, expected)
# Out:
# Power_divergenceResult(statistic=40.0, pvalue=1.065509033425585e-08)

# %%
expected
# Out:
# array([10., 10., 10., 10.])

# %%
0.5 + (1/3) + 4.5
# Out:
# 5.333333333333333

# %%
(1/3) + (1/4) + (9/3)
# Out:
# 3.583333333333333

# %%
arr1 = [1000,1001,1002]; arr2 = [999, 1000, 999]
chi  = chi_sq(arr1,arr2)
chi
# Out:
# 0.01101001001001001

# %% [markdown]
# ---
#
# # CHI SQ DIST

# %%
# GAUSSIAN PARAMETERS
A1 = 10; s1 = 30; m1 = 200
A2 = 3; s2 = 80; m2 = 400

noise_std = 1.5

its = 1000
chi_arr = []
chi_arr_noise = []

for i in range(its):

    # -- SIG SIM -- #
    
    # data
    y_arr, noise = gen_double_gauss_signal(noise_std, A1,A2, s1,s2, m1,m2)
    x_arr = np.arange(0, len(y_arr))
    
    # ---------
    # best fit
    popt, pcov = curve_fit(double_gauss, x_arr, y_arr , p0 = [5, 5, 50,50, 200,400])
    fit_arr     = np.array([double_gauss(x, *popt) for x in range(800)])
    
    chi_sig      = chi_sq(y_arr, fit_arr)
    chi_arr.append(np.sqrt(chi_sig))

    # --- NOISE --- #
    
    # best fit
    popt, pcov = curve_fit(double_gauss, x_arr, noise , p0 = [1, 1, 50,50, 200,400])
    fit_arr_noise     = np.array([double_gauss(x, *popt) for x in range(800)])

    chi_sig_noise      = chi_sq(noise, fit_arr_noise)
    chi_arr_noise.append(np.sqrt(chi_sig_noise))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_95968/122280266.py in <module>
#      28
#      29     # best fit
# ---> 30     popt, pcov = curve_fit(double_gauss, x_arr, noise , p0 = [1, 1, 50,50, 200,400])
#      31     fit_arr_noise     = np.array([double_gauss(x, *popt) for x in range(800)])
#      32
#
# /usr/lib/python3/dist-packages/scipy/optimize/_minpack_py.py in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, **kwargs)
#     792         cost = np.sum(infodict['fvec'] ** 2)
#     793         if ier not in [1, 2, 3, 4]:
# --> 794             raise RuntimeError("Optimal parameters not found: " + errmsg)
#     795     else:
#     796         # Rename maxfev (leastsq) to max_nfev (least_squares), if specified.
#
# RuntimeError: Optimal parameters not found: Number of calls to function has reached maxfev = 1400.

# %%
plt.hist(chi_arr, bins = 75)
#plt.xscale('log')
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  0.,  1.,  0.,  1.,  1.,  3.,  1.,  0.,
#          3.,  2.,  5.,  4.,  9.,  9.,  6., 14., 19., 15., 16.,  9., 26.,
#         25., 27., 21., 26., 30., 33., 37., 27., 39., 38., 35., 26., 29.,
#         36., 32., 30., 30., 33., 30., 29., 26., 27., 22., 13., 21., 19.,
#         14., 10., 15., 14., 21.,  5.,  2.,  7.,  3.,  4.,  3.,  1.,  2.,
#          2.,  4.,  0.,  0.,  1.,  1.,  2.,  1.,  1.,  1.]),
#  array([1.37099505, 1.37420428, 1.37741351, 1.38062274, 1.38383197,
#         1.3870412 , 1.39025043, 1.39345966, 1.39666889, 1.39987812,
#         1.40308735, 1.40629658, 1.40950581, 1.41271504, 1.41592427,
#         1.4191335 , 1.42234273, 1.42555196, 1.42876119, 1.43197042,
#         1.43517965, 1.43838888, 1.44159811, 1.44480734, 1.44801657,
#         1.4512258 , 1.45443503, 1.45764426, 1.46085349, 1.46406272,
#         1.46727195, 1.47048118, 1.47369041, 1.47689964, 1.48010887,
#         1.4833181 , 1.48652733, 1.48973656, 1.49294579, 1.49615502,
#         1.49936425, 1.50257348, 1.50578271, 1.50899194, 1.51220117,
#         1.5154104 , 1.51861963, 1.52182886, 1.52503809, 1.52824732,
#         1.53145655, 1.53466578, 1.53787501, 1.54108424, 1.54429347,
#         1.5475027 , 1.55071193, 1.55392116, 1.55713039, 1.56033962,
#         1.56354885, 1.56675808, 1.56996731, 1.57317654, 1.57638577,
#         1.579595  , 1.58280423, 1.58601346, 1.58922269, 1.59243192,
#         1.59564115, 1.59885038, 1.6020596 , 1.60526883, 1.60847806,
#         1.61168729]),
#  <BarContainer object of 75 artists>)

# %% [markdown]
# # char gpt
